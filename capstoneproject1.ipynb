# %% [markdown]
# <a href="https://colab.research.google.com/github/erikaguiracocha/Capstone-Project/blob/main/capstoneproject1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Uploaded police budgets

# %%
import pandas as pd
from tabulate import tabulate

# Cargar el archivo CSV desde el URL de GitHub
url = "https://raw.githubusercontent.com/erikaguiracocha/Data-Visualization-2025/refs/heads/main/Police%20budgets.csv"
df_police_budget = pd.read_csv(url)

# Asegurarse de que la columna 'Year' sea de tipo numérico para realizar el filtro
df_police_budget['Year'] = pd.to_numeric(df_police_budget['Year'], errors='coerce')

# Filtrar los datos para los años de 2013 a 2023
df_filtered = df_police_budget[(df_police_budget['Year'] >= 2013) & (df_police_budget['Year'] <= 2023)]

# Mostrar el DataFrame filtrado de forma bonita usando tabulate
print(tabulate(df_filtered, headers='keys', tablefmt='pretty', showindex=False))
# Out:
# +------+-----------------------+---------------+---------------+---------------------+----------------+
# | Year | Hamilton Township, NJ |  Trenton, NJ  |   Ewing, NJ   | Morris Township, NJ |   Newark, NJ   |
# +------+-----------------------+---------------+---------------+---------------------+----------------+
# | 2013 |     23,855,414.57     | 28,458,963.00 | 10,480,000.00 |    5,972,272.53     | 134,899,555.00 |
# | 2014 |     23,480,796.19     | 29,286,689.00 | 10,214,000.00 |    5,774,320.45     | 134,698,652.00 |
# | 2015 |     23,963,229.75     | 31,677,855.92 | 10,123,697.00 |    5,925,040.22     | 132,262,072.00 |
# | 2016 |     24,558,184.00     | 31,996,798.42 | 10,305,301.00 |    5,956,911.47     | 136,781,114.00 |
# | 2017 |     25,283,495.00     | 34,207,198.80 | 10,878,250.00 |    6,056,124.88     | 144,999,006.00 |
# | 2018 |     24,743,015.00     | 33,321,642.00 | 10,855,930.00 |    5,984,826.69     | 138,627,086.00 |
# ...

# %%
import pandas as pd

# Cargar el archivo CSV desde el URL de GitHub
url = "https://raw.githubusercontent.com/erikaguiracocha/Data-Visualization-2025/refs/heads/main/Police%20budgets.csv"
df_police_budget = pd.read_csv(url)

# Ver las primeras filas del DataFrame para verificar que los datos se cargaron correctamente
df_police_budget.head()
# Out:
#    Year Hamilton Township, NJ    Trenton, NJ      Ewing, NJ  \
# 0  2013         23,855,414.57  28,458,963.00  10,480,000.00
# 1  2014         23,480,796.19  29,286,689.00  10,214,000.00
# 2  2015         23,963,229.75  31,677,855.92  10,123,697.00
# 3  2016         24,558,184.00  31,996,798.42  10,305,301.00
# 4  2017         25,283,495.00  34,207,198.80  10,878,250.00
#
#   Morris Township, NJ      Newark, NJ
# 0        5,972,272.53  134,899,555.00
# 1        5,774,320.45  134,698,652.00
# 2        5,925,040.22  132,262,072.00
# 3        5,956,911.47  136,781,114.00
# 4        6,056,124.88  144,999,006.00

# %%
import pandas as pd

# URL del archivo CSV en GitHub
url = "https://raw.githubusercontent.com/erikaguiracocha/Data-Visualization-2025/refs/heads/main/Police%20budgets.csv"

# Cargar los datos desde el archivo CSV en GitHub
df_police_budget = pd.read_csv(url)

# Eliminar las comas de los valores para convertirlos a números
df_police_budget = df_police_budget.replace({',': ''}, regex=True)

# Convertir las columnas a tipo numérico
df_police_budget = df_police_budget.apply(pd.to_numeric, errors='coerce')

# Ver las primeras filas para revisar los datos
df_police_budget.head()

# Estadísticas descriptivas por ciudad
cities = ['Hamilton Township, NJ', 'Trenton, NJ', 'Ewing, NJ', 'Morris Township, NJ', 'Newark, NJ']

# Calculando estadísticas
stats = {}
for city in cities:
    stats[city] = {
        'Average': df_police_budget[city].mean(),
        'Median': df_police_budget[city].median(),
        'Mode': df_police_budget[city].mode()[0],  # Moda (consideramos el primer valor si hay más de una)
        'Max': df_police_budget[city].max(),
        'Min': df_police_budget[city].min()
    }

# Convertir el diccionario de estadísticas a un DataFrame para mejor presentación
stats_df = pd.DataFrame(stats)

# Ajustar el formato a dólares
pd.options.display.float_format = '${:,.2f}'.format

# Mostrar las estadísticas
stats_df
# Out:
#          Hamilton Township, NJ    Trenton, NJ      Ewing, NJ  \
# Average         $25,295,107.64 $32,353,539.21 $10,719,913.25
# Median          $24,917,096.52 $33,321,642.00 $10,855,930.00
# Mode            $23,480,796.19 $28,458,963.00 $10,123,697.00
# Max             $28,072,436.00 $35,679,708.93 $11,323,300.00
# Min             $23,480,796.19 $28,458,963.00 $10,123,697.00
#
#          Morris Township, NJ      Newark, NJ
# Average        $6,109,930.31 $146,543,433.73
# Median         $6,056,124.88 $144,999,006.00
# Mode           $5,774,320.45 $132,262,072.00
# Max            $6,464,630.59 $163,484,254.00
# Min            $5,774,320.45 $132,262,072.00

# %% [markdown]
# #uploaded fire budgets

# %%
import pandas as pd

# URL del archivo CSV para los presupuestos de bomberos
url_fire_budget = "https://raw.githubusercontent.com/erikaguiracocha/Data-Visualization-2025/refs/heads/main/Fire%20budgets.csv"

# Cargar el archivo CSV en un DataFrame
df_fire_budget = pd.read_csv(url_fire_budget)

# Verificar las primeras filas de los datos cargados
df_fire_budget.head()
# Out:
#   Year  Hamilton Township, NJ    Trenton, NJ     Ewing, NJ  \
# 0  2013          4,494,789.00  35,915,808.06  3,836,644.00
# 1  2014          4,301,152.00  33,687,033.00  3,751,619.00
# 2  2015          4,353,448.00  36,573,526.51  3,315,927.00
# 3  2016          4,742,449.00  37,485,599.87  3,899,483.00
# 4  2017          4,758,183.00  36,545,633.06  4,297,917.00
#
#   Morris Township, NJ      Newark, NJ
# 0        3,520,321.00  245,469,817.00
# 1        3,676,545.00  247,936,066.00
# 2        3,498,002.52  247,123,839.00
# 3        3,559,126.00  252,439,913.00
# 4        4,259,696.40  260,985,007.00

# %%
import pandas as pd

# URL del archivo CSV para los presupuestos de bomberos
url_fire_budget = "https://raw.githubusercontent.com/erikaguiracocha/Data-Visualization-2025/refs/heads/main/Fire%20budgets.csv"

# Cargar el archivo CSV en un DataFrame
df_fire_budget = pd.read_csv(url_fire_budget)

# Limpiar los valores eliminando las comas y convertir a tipo numérico
for column in df_fire_budget.columns[1:]:  # Omitir la columna 'Year'
    df_fire_budget[column] = df_fire_budget[column].replace({',': ''}, regex=True)  # Eliminar las comas
    df_fire_budget[column] = pd.to_numeric(df_fire_budget[column], errors='coerce')  # Convertir a numérico

# Verificar las primeras filas de los datos limpiados
print(df_fire_budget.head())

# Establecer el formato de moneda para las salidas
def format_currency(x):
    return f"${x:,.2f}"

# Calcular las estadísticas descriptivas
stats = {}

# Obtener el nombre de las ciudades
cities = df_fire_budget.columns[1:]

# Calcular la media, mediana, moda, máximo y mínimo por cada ciudad
for city in cities:
    stats[city] = {
        'Average': format_currency(df_fire_budget[city].mean()),
        'Median': format_currency(df_fire_budget[city].median()),
        'Mode': format_currency(df_fire_budget[city].mode()[0]),  # Moda (consideramos el primer valor si hay más de una)
        'Max': format_currency(df_fire_budget[city].max()),
        'Min': format_currency(df_fire_budget[city].min())
    }

# Convertir el resultado a un DataFrame para presentación más clara
df_stats = pd.DataFrame(stats)

# Mostrar las estadísticas descriptivas
df_stats
# Out:
#   Year   Hamilton Township, NJ    Trenton, NJ     Ewing, NJ  \
# 0  2013          $4,494,789.00 $35,915,808.06 $3,836,644.00
# 1  2014          $4,301,152.00 $33,687,033.00 $3,751,619.00
# 2  2015          $4,353,448.00 $36,573,526.51 $3,315,927.00
# 3  2016          $4,742,449.00 $37,485,599.87 $3,899,483.00
# 4  2017          $4,758,183.00 $36,545,633.06 $4,297,917.00
#
#    Morris Township, NJ      Newark, NJ
# 0        $3,520,321.00 $245,469,817.00
# 1        $3,676,545.00 $247,936,066.00
# 2        $3,498,002.52 $247,123,839.00
# 3        $3,559,126.00 $252,439,913.00
# 4        $4,259,696.40 $260,985,007.00
#         Hamilton Township, NJ      Trenton, NJ       Ewing, NJ  \
# Average        $21,924,365.39   $73,803,073.42   $9,125,661.67
# Median          $5,375,579.50   $41,458,309.48   $5,330,653.50
# Mode            $4,301,152.00   $33,687,033.00   $3,315,927.00
# Max           $131,546,192.33  $442,818,440.49  $54,753,970.00
# ...

# %% [markdown]
# #Income media

# %%
import pandas as pd

# Cargar el archivo CSV desde el enlace
url = "https://raw.githubusercontent.com/erikaguiracocha/Data-Visualization-2025/refs/heads/main/Income%20Media.csv"
data = pd.read_csv(url)

# Verificar que los datos se cargaron correctamente
data.head()
# Out:
#    Year Hamilton Township, NJ Trenton, NJ  Ewing, NJ  Morris Township, NJ   \
# 0  2013               76,000      38,000       97852                 93276
# 1  2014               77,000      39,000      100119                 97815
# 2  2015               78,000      40,000       99927                 99853
# 3  2016               80,000      41,000       97480                105749
# 4  2017               82,000      43,000       92945                115095
#
#    Newark, NJ
# 0       44615
# 1       43951
# 2       42749
# 3       42058
# 4       43429

# %% [markdown]
# #Response times

# %%
import pandas as pd

# Cargar el archivo CSV desde el enlace
url = "https://raw.githubusercontent.com/erikaguiracocha/Data-Visualization-2025/refs/heads/main/time%20of%20responses.csv"
data = pd.read_csv(url)

# Verificar que los datos se cargaron correctamente
data.head()
# Out:
#    Year Hamilton Towship, NJ Trenton, NJ Ewing, NJ  Morris Township, NJ  \
# 0  2013                 3:02        2:54       1:50                1:05
# 1  2014                 3:02        2:54       1:51                1:06
# 2  2015                 3:03        2:55       1:52                1:06
# 3  2016                 3:04        2:56       1:53                1:07
# 4  2017                 3:04        2:56       1:53                1:07
#
#   Newark, NJ
# 0       4:34
# 1       4:37
# 2       4:41
# 3       4:45
# 4       4:47

# %% [markdown]
# #GRAPH FOR UNEMPLOYMENT

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar el archivo CSV desde el enlace
url = "https://raw.githubusercontent.com/erikaguiracocha/Data-Visualization-2025/refs/heads/main/unemployment%20rates.csv"
data = pd.read_csv(url)

# Filtrar los datos para los años entre 2013 y 2023
filtered_data = data[(data['Year'] >= 2013) & (data['Year'] <= 2023)]

# Graficar las tasas de desempleo a lo largo de los años para cada ciudad
plt.figure(figsize=(12, 8))

# Graficar para cada ciudad
for city in filtered_data.columns[1:]:  # Excluimos la columna 'Year'
    plt.plot(filtered_data['Year'], filtered_data[city], label=city, marker='o')

# Agregar título y etiquetas
plt.title('Tasas de Desempleo (2013-2023)', fontsize=16)
plt.xlabel('Año', fontsize=12)
plt.ylabel('Tasa de Desempleo (%)', fontsize=12)

# Mejorar visualización
plt.xticks(filtered_data['Year'], rotation=45)  # Asegurarse de que todos los años estén visibles
plt.grid(True)
plt.legend(title="Ciudades", bbox_to_anchor=(1.05, 1), loc='upper left')

# Mostrar el gráfico
plt.tight_layout()  # Ajusta el gráfico para que no se corte
plt.show()

# %% [markdown]
# #CORRELATION ANALYSIS

# %%
import pandas as pd
import numpy as np

# Datos de tiempos de respuesta
response_data = {
    'Year': [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
    'Hamilton Township, NJ': ['3:02', '3:02', '3:03', '3:04', '3:04', '3:04', '3:05', '3:06', '3:06', '3:06', '3:07'],
    'Trenton, NJ': ['2:54', '2:54', '2:55', '2:56', '2:56', '2:57', '2:58', '2:59', '2:59', '2:59', '3:00'],
    'Ewing, NJ': ['1:50', '1:51', '1:52', '1:53', '1:53', '1:54', '1:54', '1:54', '1:54', '1:53', '1:55'],
    'Morris Township, NJ': ['1:05', '1:06', '1:06', '1:07', '1:07', '1:08', '1:08', '1:08', '1:08', '1:08', '1:08'],
    'Newark, NJ': ['4:34', '4:37', '4:41', '4:45', '4:47', '4:50', '4:52', '4:55', '4:57', '5:00', '5:05']
}

# Datos de presupuestos de fire
fire_budget_data = {
    'Year': [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
    'Hamilton Township, NJ': [4494789, 4301152, 4353448, 4742449, 4758183, 5141843, 5658747, 5609316, 30621000, 29738129.95, 32127135.38],
    'Trenton, NJ': [35915808.06, 33687033, 36573526.51, 37485599.87, 36545633.06, 39636399.23, 43280219.74, 44208633.39, 44655105, 44743022.66, 46087459.97],
    'Ewing, NJ': [3836644, 3751619, 3315927, 3899483, 4297917, 5151764, 5509543, 5839373, 6149993, 6182807, 6818900],
    'Morris Township, NJ': [3520321, 3676545, 3498002.52, 3559126, 4259696.4, 3731605.33, 2329614.12, 2478635.56, 4281720.17, 4534326.44, 4935977.09],
    'Newark, NJ': [245469817, 247936066, 247123839, 252439913, 260985007, 250636333, 281758976, 274586387, 300350612, 230824120, 315051003]
}

# Datos de presupuestos de police
police_budget_data = {
    'Year': [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
    'Hamilton Township, NJ': [23855414.57, 23480796.19, 23963229.75, 24558184, 25283495, 24743015, 25461511.96, 24917096.52, 26324040, 27586965, 28072436],
    'Trenton, NJ': [28458963, 29286689, 31677855.92, 31996798.42, 34207198.8, 33321642, 35037749.07, 33478331.85, 33430800, 29313194.35, 35679708.93],
    'Ewing, NJ': [10480000, 10214000, 10123697, 10305301, 10878250, 10855930, 11323300, 11200001, 10479003, 11030563.74, 11029000],
    'Morris Township, NJ': [5972272.53, 5774320.45, 5925040.22, 5956911.47, 6056124.88, 5984826.69, 6062547.21, 6173672.36, 6411032.51, 6464630.59, 6427854.48],
    'Newark, NJ': [134899555, 134698652, 132262072, 136781114, 144999006, 138627086, 155550247, 146120143, 161599427, 163484254, 162956215]
}

# Convertir tiempos de respuesta de formato 'min:seg' a minutos flotantes
def convert_time(time_str):
    minutes, seconds = map(int, time_str.split(':'))
    return minutes + seconds / 60.0

# Convertir los tiempos de respuesta
for city in response_data.keys():
    if city != 'Year':
        response_data[city] = [convert_time(time) for time in response_data[city]]

# Crear DataFrame para tiempos de respuesta
df_response = pd.DataFrame(response_data)

# Crear DataFrame para presupuestos de fire y police
df_fire_budget = pd.DataFrame(fire_budget_data)
df_police_budget = pd.DataFrame(police_budget_data)

# Calcular correlaciones entre los presupuestos y los tiempos de respuesta
fire_correlation = df_response.corrwith(df_fire_budget.drop('Year', axis=1))
police_correlation = df_response.corrwith(df_police_budget.drop('Year', axis=1))

# Mostrar los resultados
correlation_results = pd.DataFrame({
    'Fire Correlation': fire_correlation,
    'Police Correlation': police_correlation
})

print(correlation_results)
# Out:
#                        Fire Correlation  Police Correlation
# Hamilton Township, NJ          0.739887            0.880387
# Trenton, NJ                    0.977916            0.606567
# Ewing, NJ                      0.782557            0.636309
# Morris Township, NJ            0.076558            0.667760
# Newark, NJ                     0.601049            0.891306
# Year                                NaN                 NaN

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# URLs para los datasets
fire_budget_url = "https://raw.githubusercontent.com/erikaguiracocha/Data-Visualization-2025/refs/heads/main/Fire%20budgets.csv"
police_budget_url = "https://raw.githubusercontent.com/erikaguiracocha/Data-Visualization-2025/refs/heads/main/Police%20budgets.csv"
response_time_url = "https://raw.githubusercontent.com/erikaguiracocha/Data-Visualization-2025/refs/heads/main/time%20of%20responses.csv"

# Cargar los datasets
fire_budget_data = pd.read_csv(fire_budget_url)
police_budget_data = pd.read_csv(police_budget_url)
response_time_data = pd.read_csv(response_time_url)

# Limpiar los nombres de las columnas (eliminar espacios en blanco)
fire_budget_data.columns = fire_budget_data.columns.str.strip()
police_budget_data.columns = police_budget_data.columns.str.strip()
response_time_data.columns = response_time_data.columns.str.strip()

# Corregir errores tipográficos en los nombres de las ciudades
response_time_data = response_time_data.rename(columns={'Hamilton Towship, NJ': 'Hamilton Township, NJ'})

# Convertir 'Year' a tipo numérico y eliminar filas con valores no numéricos
def clean_year_column(df):
    df = df[pd.to_numeric(df['Year'], errors='coerce').notnull()]  # Eliminar filas con valores no numéricos
    df['Year'] = df['Year'].astype(int)  # Convertir la columna 'Year' a tipo entero
    return df

# Limpiar todos los datasets
fire_budget_data = clean_year_column(fire_budget_data)
police_budget_data = clean_year_column(police_budget_data)
response_time_data = clean_year_column(response_time_data)

# Función para limpiar las columnas de presupuesto y convertirlas a float
def clean_budget_columns(df, budget_columns):
    for col in budget_columns:
        df[col] = df[col].replace({',': ''}, regex=True)  # Eliminar comas
        df[col] = df[col].astype(float)  # Convertir a float
    return df

# Limpiar columnas de presupuesto
fire_budget_columns = ['Hamilton Township, NJ', 'Trenton, NJ', 'Ewing, NJ', 'Morris Township, NJ', 'Newark, NJ']
police_budget_columns = ['Hamilton Township, NJ', 'Trenton, NJ', 'Ewing, NJ', 'Morris Township, NJ', 'Newark, NJ']

# Limpiar presupuestos
fire_budget_data = clean_budget_columns(fire_budget_data, fire_budget_columns)
police_budget_data = clean_budget_columns(police_budget_data, police_budget_columns)

# Función para convertir el tiempo en formato 'hh:mm' a minutos
def convert_time_to_minutes(df, time_columns):
    for col in time_columns:
        df[col] = df[col].apply(lambda x: int(x.split(':')[0])*60 + int(x.split(':')[1]))  # Convertir a minutos
    return df

# Columnas de tiempo de respuesta
time_columns = ['Hamilton Township, NJ', 'Trenton, NJ', 'Ewing, NJ', 'Morris Township, NJ', 'Newark, NJ']

# Convertir los tiempos de respuesta a minutos
response_time_data = convert_time_to_minutes(response_time_data, time_columns)

# Fusionar los datasets en la columna 'Year'
merged_data = pd.merge(fire_budget_data, police_budget_data, on='Year', suffixes=('_fire', '_police'))
merged_data = pd.merge(merged_data, response_time_data, on='Year')

# Calcular la correlación entre las variables
correlation = merged_data[['Hamilton Township, NJ_fire', 'Trenton, NJ_fire', 'Ewing, NJ_fire', 'Morris Township, NJ_fire', 'Newark, NJ_fire',
                           'Hamilton Township, NJ_police', 'Trenton, NJ_police', 'Ewing, NJ_police', 'Morris Township, NJ_police', 'Newark, NJ_police',
                           'Hamilton Township, NJ', 'Trenton, NJ', 'Ewing, NJ', 'Morris Township, NJ', 'Newark, NJ']].corr()

# Crear el mapa de calor
plt.figure(figsize=(12, 8))
sns.heatmap(correlation, annot=True, cmap='coolwarm', center=0, fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap between Fire and Police Budget and Response Times by City')
plt.show()
# Out:
# <ipython-input-38-a06e3a81d61a>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'] = df['Year'].astype(int)  # Convertir la columna 'Year' a tipo entero

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Example data for police and fire budgets
police_budgets = {
    "Hamilton Township, NJ": [23855414.57, 23480796.19, 23963229.75, 24558184.00, 25283495.00, 24743015.00, 25461511.96, 24917096.52, 26324040.00, 27586965.00, 28072436.00],
    "Trenton, NJ": [28458963.00, 29286689.00, 31677855.92, 31996798.42, 34207198.80, 33321642.00, 35037749.07, 33478331.85, 33430800.00, 29313194.35, 35679708.93],
    "Ewing, NJ": [10480000.00, 10214000.00, 10123697.00, 10305301.00, 10878250.00, 10855930.00, 11323300.00, 11200001.00, 10479003.00, 11030563.74, 11029000.00],
    "Morris Township, NJ": [5972272.53, 5774320.45, 5925040.22, 5956911.47, 6056124.88, 5984826.69, 6062547.21, 6173672.36, 6411032.51, 6464630.59, 6427854.48],
    "Newark, NJ": [134899555.00, 134698652.00, 132262072.00, 136781114.00, 144999006.00, 138627086.00, 155550247.00, 146120143.00, 161599427.00, 163484254.00, 162956215.00]
}

fire_budgets = {
    "Hamilton Township, NJ": [4494789, 4301152, 4353448, 4742449, 4758183, 5141843, 5658747, 5609316, 30621000, 29738129, 32127135],
    "Trenton, NJ": [35915808, 33687033, 36573526, 37485599, 36545633, 39636399, 43280219, 44208633, 44655105, 44743022, 46087459],
    "Ewing, NJ": [3836644, 3751619, 3315927, 3899483, 4297917, 5151764, 5509543, 5839373, 6149993, 6182807, 6818900],
    "Morris Township, NJ": [3520321, 3676545, 3498002, 3559126, 4259696, 3731605, 2329614, 2478635, 4281720, 4534326, 4935977],
    "Newark, NJ": [245469817, 247936066, 247123839, 252439913, 260985007, 250636333, 281758976, 274586387, 300350612, 230824120, 315051003]
}

# Example response times in minutes
response_times = {
    "Hamilton Township, NJ": [3.02, 3.02, 3.03, 3.04, 3.04, 3.04, 3.05, 3.06, 3.06, 3.06, 3.07],
    "Trenton, NJ": [2.54, 2.54, 2.55, 2.56, 2.56, 2.57, 2.58, 2.59, 2.59, 2.59, 3.00],
    "Ewing, NJ": [1.50, 1.51, 1.52, 1.53, 1.53, 1.54, 1.54, 1.54, 1.54, 1.53, 1.55],
    "Morris Township, NJ": [1.05, 1.06, 1.06, 1.07, 1.07, 1.08, 1.08, 1.08, 1.08, 1.08, 1.08],
    "Newark, NJ": [4.34, 4.37, 4.41, 4.45, 4.47, 4.50, 4.52, 4.55, 4.57, 5.00, 5.05]
}

# Convert dictionaries to DataFrames
df_fire = pd.DataFrame(fire_budgets)
df_police = pd.DataFrame(police_budgets)
df_response = pd.DataFrame(response_times)

# Create a scatter plot comparing Response Time (x-axis) vs Police & Fire budgets (y-axis)
plt.figure(figsize=(12, 8))

# Scatter plot for Fire Budget vs Response Time (Fire data on Y-axis)
for city in df_fire.columns:
    plt.scatter(df_response[city], df_fire[city]/1e6, label=f'{city} (Fire)', alpha=0.7)

# Scatter plot for Police Budget vs Response Time (Police data on Y-axis)
for city in df_police.columns:
    plt.scatter(df_response[city], df_police[city]/1e6, label=f'{city} (Police)', alpha=0.7)

# Add title and labels in English
plt.title("Scatter Plot: Response Time vs Police & Fire Budget (in Millions)")
plt.xlabel("Response Time (in minutes)")
plt.ylabel("Budget in Dollars (Millions)")

# Add a legend
plt.legend(title="City (Service Type)")

# Add grid for better visualization
plt.grid(True)

# Display the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Example data for police and fire budgets
police_budgets = {
    "Hamilton Township, NJ": [23855414.57, 23480796.19, 23963229.75, 24558184.00, 25283495.00, 24743015.00, 25461511.96, 24917096.52, 26324040.00, 27586965.00, 28072436.00],
    "Trenton, NJ": [28458963.00, 29286689.00, 31677855.92, 31996798.42, 34207198.80, 33321642.00, 35037749.07, 33478331.85, 33430800.00, 29313194.35, 35679708.93],
    "Ewing, NJ": [10480000.00, 10214000.00, 10123697.00, 10305301.00, 10878250.00, 10855930.00, 11323300.00, 11200001.00, 10479003.00, 11030563.74, 11029000.00],
    "Morris Township, NJ": [5972272.53, 5774320.45, 5925040.22, 5956911.47, 6056124.88, 5984826.69, 6062547.21, 6173672.36, 6411032.51, 6464630.59, 6427854.48],
    "Newark, NJ": [134899555.00, 134698652.00, 132262072.00, 136781114.00, 144999006.00, 138627086.00, 155550247.00, 146120143.00, 161599427.00, 163484254.00, 162956215.00]
}

fire_budgets = {
    "Hamilton Township, NJ": [4494789, 4301152, 4353448, 4742449, 4758183, 5141843, 5658747, 5609316, 30621000, 29738129, 32127135],
    "Trenton, NJ": [35915808, 33687033, 36573526, 37485599, 36545633, 39636399, 43280219, 44208633, 44655105, 44743022, 46087459],
    "Ewing, NJ": [3836644, 3751619, 3315927, 3899483, 4297917, 5151764, 5509543, 5839373, 6149993, 6182807, 6818900],
    "Morris Township, NJ": [3520321, 3676545, 3498002, 3559126, 4259696, 3731605, 2329614, 2478635, 4281720, 4534326, 4935977],
    "Newark, NJ": [245469817, 247936066, 247123839, 252439913, 260985007, 250636333, 281758976, 274586387, 300350612, 230824120, 315051003]
}

# Example response times in minutes
response_times = {
    "Hamilton Township, NJ": [3.02, 3.02, 3.03, 3.04, 3.04, 3.04, 3.05, 3.06, 3.06, 3.06, 3.07],
    "Trenton, NJ": [2.54, 2.54, 2.55, 2.56, 2.56, 2.57, 2.58, 2.59, 2.59, 2.59, 3.00],
    "Ewing, NJ": [1.50, 1.51, 1.52, 1.53, 1.53, 1.54, 1.54, 1.54, 1.54, 1.53, 1.55],
    "Morris Township, NJ": [1.05, 1.06, 1.06, 1.07, 1.07, 1.08, 1.08, 1.08, 1.08, 1.08, 1.08],
    "Newark, NJ": [4.34, 4.37, 4.41, 4.45, 4.47, 4.50, 4.52, 4.55, 4.57, 5.00, 5.05]
}

# Convert dictionaries to DataFrames
df_fire = pd.DataFrame(fire_budgets)
df_police = pd.DataFrame(police_budgets)
df_response = pd.DataFrame(response_times)

# Create a scatter plot comparing Response Time (x-axis) vs Police & Fire budgets (y-axis)
plt.figure(figsize=(12, 8))

# Scatter plot for Fire Budget vs Response Time (Fire data on Y-axis)
for city in df_fire.columns:
    plt.scatter(df_response[city], df_fire[city]/1e6, label=f'{city} (Fire)', alpha=0.7)

# Scatter plot for Police Budget vs Response Time (Police data on Y-axis)
for city in df_police.columns:
    plt.scatter(df_response[city], df_police[city]/1e6, label=f'{city} (Police)', alpha=0.7)

# Add title and labels in English
plt.title("Scatter Plot: Response Time vs Police & Fire Budget (in Millions)")
plt.xlabel("Response Time (in minutes)")
plt.ylabel("Budget in Dollars (Millions)")

# Add a legend
plt.legend(title="City (Service Type)")

# Add grid for better visualization
plt.grid(True)

# Set the y-axis to have a range that fits the scale of budgets in millions (from 0 to 350)
plt.ylim(0, 350)  # Setting the range from 0 to 350 million dollars

# Display the plot
plt.show()
